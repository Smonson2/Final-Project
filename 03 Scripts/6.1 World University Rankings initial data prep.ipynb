# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing Data and Creating path
df = pd.read_csv(r'C:\Users\steph\OneDrive\Documents\Sept 2022 Worl University Rankings\02 Data\Original Data\World University Rankings Raw Data.csv')

# %%
path = r"C:\Users\steph\OneDrive\Documents\Sept 2022 Worl University Rankings"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   world_rank            2200 non-null   int64
#  1   institution           2200 non-null   object
#  2   country               2200 non-null   object
#  3   national_rank         2200 non-null   int64
#  4   quality_of_education  2200 non-null   int64
#  5   alumni_employment     2200 non-null   int64
#  6   quality_of_faculty    2200 non-null   int64
#  7   publications          2200 non-null   int64
#  8   influence             2200 non-null   int64
#  9   citations             2200 non-null   int64
#  10  broad_impact          2000 non-null   float64
#  11  patents               2200 non-null   int64
#  12  score                 2200 non-null   float64
#  13  year                  2200 non-null   int64
# dtypes: float64(2), int64(10), object(2)
# ...

# %%
# Look for null values
df.isnull().sum()
# Out:
# world_rank                0
# institution               0
# country                   0
# national_rank             0
# quality_of_education      0
# alumni_employment         0
# quality_of_faculty        0
# publications              0
# influence                 0
# citations                 0
# broad_impact            200
# patents                   0
# score                     0
# year                      0
# dtype: int64

# %%
# Delete Column 'broad_impact' due to null values
del df['broad_impact']
df
# Out:
#       world_rank                            institution               country  \
# 0            986                University of Bucharest               Romania
# 1            962  University of Puerto Rico at Mayagüez           Puerto Rico
# 2            950        United Arab Emirates University  United Arab Emirates
# 3            928                   University of Cyprus                Cyprus
# 4             93               University of Copenhagen               Denmark
# ...          ...                                    ...                   ...
# 2195         913     University of Southern Mississippi                   USA
# 2196         929         University of Texas at El Paso                   USA
# 2197         923       University of California, Merced                   USA
# 2198         936       University of California, Merced                   USA
# 2199         969            Western Michigan University                   USA
#
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2195    False
# 2196    False
# 2197    False
# 2198    False
# 2199    False
# Length: 2200, dtype: bool

# %%
df.rename(columns = {'citations' : 'number_of_students'}, inplace = True)

# %%
df.head()
# Out:
#    world_rank                            institution               country  \
# 0         986                University of Bucharest               Romania
# 1         962  University of Puerto Rico at Mayagüez           Puerto Rico
# 2         950        United Arab Emirates University  United Arab Emirates
# 3         928                   University of Cyprus                Cyprus
# 4          93               University of Copenhagen               Denmark
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                   237                567                 218
# 1              1                   367                567                 218
# 2              1                   367                521                 218
# 3              1                   367                567                 218
# 4              1                   101                101                  60
#
# ...

# %%
# Obtain Descriptive Statistics  and profile of Cleaned Data
df.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence  number_of_students  \
# count         2200.000000   2200.000000  2200.000000         2200.000000
# mean           178.888182    459.908636   459.797727          413.417273
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   world_rank            2200 non-null   int64
#  1   institution           2200 non-null   object
#  2   country               2200 non-null   object
#  3   national_rank         2200 non-null   int64
#  4   quality_of_education  2200 non-null   int64
#  5   alumni_employment     2200 non-null   int64
#  6   quality_of_faculty    2200 non-null   int64
#  7   publications          2200 non-null   int64
#  8   influence             2200 non-null   int64
#  9   number_of_students    2200 non-null   int64
#  10  patents               2200 non-null   int64
#  11  score                 2200 non-null   float64
#  12  year                  2200 non-null   int64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 223.6+ KB

# %%
df.to_pickle(r'C:\Users\steph\OneDrive\Documents\Sept 2022 Worl University Rankings\02 Data\Prepared Data\Rankings_prepared.pkl')
